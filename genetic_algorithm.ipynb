# %%
import random
source = "ABCDELOhmel'd"
target = "Hello, World!"

def fitness(source, target):
   fitval = 0
   for i in range(0, len(source)):
      fitval += (ord(target[i]) - ord(source[i])) ** 2
   return(fitval)

# %%
def mutate(source):
    charpos = random.randint(0, len(source) - 1)
    parts = list(source)
    parts[charpos] = chr(ord(parts[charpos]) + random.randint(-1,1))
    return(''.join(parts))

fitval = fitness(source, target)
i = 0
while True:
    i += 1
    m = mutate(source)
    fitval_m = fitness(m, target)
    if fitval_m < fitval:
        fitval = fitval_m
        source = m
        print(i, fitval_m, m)
    if fitval == 0:
        break
# Out:
# 1 18199 ABCDELOhmfl'd
# 5 18136 ABCDEKOhmfl'd
# 9 18075 ABCDEJOhmfl'd
# 13 18016 ABCDEIOhmfl'd
# 14 17947 ACCDEIOhmfl'd
# 15 17826 ACCDEIOhmfl(d
# 16 17693 ACCDEIOhmfl(c
# 20 17636 ACCDEHOhmfl(c
# 25 17505 ACCDEHOhmfl(b
# 27 17426 ACCEEHOhmfl(b
# 28 17333 ACCEEHNhmfl(b
# 29 17204 ACCEEHNhmfl(a
# 30 17121 ACCEFHNhmfl(a
# 35 17054 ADCEFHNhmfl(a
# 36 16999 ADCEFGNhmfl(a
# 37 16966 ADCEFGNgmfl(a
# 40 16885 ADDEFGNgmfl(a
# 41 16832 ADDEFFNgmfl(a
# 42 16751 ADDEGFNgmfl(a
# 50 16672 ADEEGFNgmfl(a
# 51 16553 ADEEGFNgmfl)a
# 53 16474 ADEEHFNgmfl)a
# 55 16423 ADEEHENgmfl)a
# 56 16346 ADFEHENgmfl)a
# 62 16333 BDFEHENgmfl)a
# 63 16256 BDFEIENgmfl)a
# 65 16179 BDFFIENgmfl)a
# 66 16052 BDFFIENgmfl)`
# 69 16041 CDFFIENgmfl)`
# 73 15992 CDFFIDNgmfl)`
# 82 15917 CDFGIDNgmfl)`
# 85 15800 CDFGIDNgmfl*`
# 89 15725 CDGGIDNgmfl*`
# 91 15634 CDGGIDMgmfl*`
# 96 15569 CEGGIDMgmfl*`
# 104 15494 CEGGJDMgmfl*`
# 110 15379 CEGGJDMgmfl+`
# 113 15356 CEGGJDMgmgl+`
# 116 15353 CEGGJDMgngl+`
# 117 15290 CFGGJDMgngl+`
# 118 15289 CFGGJDMgogl+`
# 119 15200 CFGGJDLgogl+`
# 120 15169 CFGGJDLfogl+`
# 125 15096 CFHGJDLfogl+`
# 127 15075 CFHGJDLfohl+`
# 128 15066 DFHGJDLfohl+`
# 130 15037 DFHGJDLeohl+`
# 134 14990 DFHGJCLeohl+`
# 136 14865 DFHGJCLeohl+_
# 137 14846 DFHGJCLeoil+_
# 144 14829 DFHGJCLeojl+_
# 147 14822 EFHGJCLeojl+_
# 155 14709 EFHGJCLeojl,_
# 158 14704 FFHGJCLeojl,_
# 161 14689 FFHGJCLeokl,_
# 162 14676 FFHGJCLeoll,_
# 172 14631 FFHGJBLeoll,_
# 175 14544 FFHGJBKeoll,_
# 176 14483 FGHGJBKeoll,_
# 177 14412 FGIGJBKeoll,_
# 183 14339 FGIGKBKeoll,_
# 184 14268 FGIGLBKeoll,_
# 186 14199 FGJGLBKeoll,_
# 190 14130 FGJGMBKeoll,_
# 195 14007 FGJGMBKeoll,^
# 196 13886 FGJGMBKeoll,]
# 202 13767 FGJGMBKeoll,\
# 207 13700 FGJGNBKeoll,\
# 209 13627 FGJHNBKeoll,\
# 218 13624 GGJHNBKeoll,\
# 223 13597 GGJHNBKdoll,\
# 224 13532 GGJHOBKdoll,\
# 228 13489 GGJHOAKdoll,\
# 229 13464 GGJHOAKcoll,\
# 232 13453 GGJHOAKcoml,\
# 234 13336 GGJHOAKcoml,[
# 235 13269 GGKHOAKcoml,[
# 237 13198 GGKIOAKcoml,[
# 242 13189 GGKIOAKconl,[
# 243 13074 GGKIOAKconl,Z
# 245 13005 GGKJOAKconl,Z
# 247 12892 GGKJOAKconl,Y
# 256 12829 GGKJPAKconl,Y
# 263 12806 GGKJPAKbonl,Y
# 266 12785 GGKJPAKaonl,Y
# 270 12718 GGKKPAKaonl,Y
# 273 12633 GGKKPAJaonl,Y
# 274 12568 GGKLPAJaonl,Y
# 275 12457 GGKLPAJaonl-Y
# 276 12450 GGKLPAJaool-Y
# 277 12449 HGKLPAJaool-Y
# 283 12408 HGKLP@Jaool-Y
# 284 12369 HGKLP?Jaool-Y
# 285 12260 HGKLP?Jaool.Y
# 292 12149 HGKLP?Jaool.X
# 295 12084 HGLLP?Jaool.X
# 297 12079 HGLLP?Jaopl.X
# 300 11996 HGLLP?Iaopl.X
# 306 11933 HGLMP?Iaopl.X
# 308 11872 HGLNP?Iaopl.X
# 309 11791 HGLNP?Haopl.X
# 310 11712 HGLNP?Gaopl.X
# 312 11649 HGMNP?Gaopl.X
# 314 11540 HGMNP?Gaopl.W
# 316 11479 HGNNP?Gaopl.W
# 322 11372 HGNNP?Gaopl.V
# 325 11313 HGNOP?Gaopl.V
# 328 11254 HGOOP?Gaopl.V
# 336 11251 HGOOP?Gaoql.V
# 338 11250 HGOOP?Gaorl.V
# 340 11189 HGOOQ?Gaorl.V
# 344 11082 HGOOQ?Gaorl/V
# 346 11023 HHOOQ?Gaorl/V
# 347 10918 HHOOQ?Gaorl0V
# 355 10859 HHOOR?Gaorl0V
# 360 10802 HIOOR?Gaorl0V
# 363 10697 HIOOR?Gaorl0U
# 367 10678 HIOOR?G`orl0U
# 370 10661 HIOOR?G_orl0U
# 371 10604 HIOOS?G_orl0U
# 378 10547 HIPOS?G_orl0U
# 386 10444 HIPOS?G_orl0T
# 387 10407 HIPOS>G_orl0T
# 396 10304 HIPOS>G_orl1T
# 399 10289 HIPOS>G^orl1T
# 402 10254 HIPOS=G^orl1T
# 403 10197 HIPPS=G^orl1T
# 406 10096 HIPPS=G^orl1S
# 407 10083 HIPPS=G]orl1S
# 416 10028 HIQPS=G]orl1S
# 418 9975 HIRPS=G]orl1S
# 425 9920 HJRPS=G]orl1S
# 450 9819 HJRPS=G]orl2S
# 452 9742 HJRPS=F]orl2S
# 455 9689 HKRPS=F]orl2S
# 459 9590 HKRPS=F]orl3S
# 464 9557 HKRPS<F]orl3S
# 471 9458 HKRPS<F]orl3R
# 474 9361 HKRPS<F]orl4R
# 479 9264 HKRPS<F]orl4Q
# 482 9209 HKRQS<F]orl4Q
# 484 9198 HKRQS<F\orl4Q
# 492 9145 HKRRS<F\orl4Q
# 493 9050 HKRRS<F\orl4P
# 495 9019 HKRRS;F\orl4P
# 496 8944 HKRRS;E\orl4P
# 500 8893 HKRSS;E\orl4P
# 503 8844 HKRTS;E\orl4P
# 505 8815 HKRTS:E\orl4P
# 506 8722 HKRTS:E\orl4O
# 510 8667 HKRTT:E\orl4O
# 517 8616 HKSTT:E\orl4O
# 519 8525 HKSTT:E\orl4N
# 520 8476 HKTTT:E\orl4N
# 522 8423 HKTTU:E\orl4N
# 523 8350 HKTTU:D\orl4N
# 528 8299 HLTTU:D\orl4N
# 533 8272 HLTTU9D\orl4N
# 534 8201 HLTTU9C\orl4N
# 536 8176 HLTTU8C\orl4N
# 537 8129 HLUTU8C\orl4N
# 548 8082 HLUUU8C\orl4N
# 549 8013 HLUUU8B\orl4N
# 550 7918 HLUUU8B\orl5N
# 556 7829 HLUUU8B\orl5M
# 560 7736 HLUUU8B\orl6M
# 571 7691 HLUVU8B\orl6M
# 574 7600 HLUVU8B\orl7M
# 579 7577 HLUVU7B\orl7M
# 580 7556 HLUVU6B\orl7M
# 581 7469 HLUVU6B\orl7L
# 589 7420 HMUVU6B\orl7L
# 590 7331 HMUVU6B\orl8L
# 595 7284 HNUVU6B\orl8L
# 597 7275 HNUVU6B[orl8L
# 600 7224 HNUVV6B[orl8L
# 602 7139 HNUVV6B[orl8K
# 608 7094 HOUVV6B[orl8K
# 612 7007 HOUVV6B[orl9K
# 613 6940 HOUVV6A[orl9K
# 620 6897 HOUWV6A[orl9K
# 622 6852 HOVWV6A[orl9K
# 625 6809 HPVWV6A[orl9K
# 626 6766 HPWWV6A[orl9K
# 628 6725 HPWXV6A[orl9K
# 633 6676 HPWXW6A[orl9K
# 634 6635 HQWXW6A[orl9K
# 636 6616 HQWXW5A[orl9K
# 640 6575 HQXXW5A[orl9K
# 649 6536 HQXYW5A[orl9K
# 651 6497 HQYYW5A[orl9K
# 652 6480 HQYYW4A[orl9K
# 657 6443 HQYZW4A[orl9K
# 661 6406 HQZZW4A[orl9K
# 663 6359 HQZZX4A[orl9K
# 665 6274 HQZZX4A[orl:K
# 669 6259 HQZZX3A[orl:K
# 674 6214 HQZZY3A[orl:K
# 683 6171 HQZZZ3A[orl:K
# 686 6136 HQ[ZZ3A[orl:K
# 688 6101 HQ[[Z3A[orl:K
# 691 6088 HQ[[Z2A[orl:K
# 694 6081 HQ[[Z2AZorl:K
# 706 6042 HR[[Z2AZorl:K
# 712 6001 HR[[[2AZorl:K
# 716 5968 HR[\[2AZorl:K
# 723 5903 HR[\[2@Zorl:K
# 726 5898 HR[\[2@Yorl:K
# 730 5861 HS[\[2@Yorl:K
# 731 5778 HS[\[2@Yorl;K
# 736 5695 HS[\[2@Yorl;J
# 740 5662 HS\\[2@Yorl;J
# 749 5659 HS\\[2@Xorl;J
# 752 5624 HT\\[2@Xorl;J
# 753 5593 HT]\[2@Xorl;J
# 760 5560 HU]\[2@Xorl;J
# 762 5497 HU]\[2?Xorl;J
# 763 5496 HU]\[2?Worl;J
# 764 5415 HU]\[2?Worl<J
# 767 5354 HU]\[2>Worl<J
# 768 5295 HU]\[2=Worl<J
# 770 5264 HU]][2=Worl<J
# 773 5183 HU]][2=Worl<I
# 774 5172 HU]][1=Worl<I
# 775 5141 HV]][1=Worl<I
# 779 5062 HV]][1=Worl<H
# 782 5033 HV^][1=Worl<H
# 791 5004 HW^][1=Worl<H
# 794 4977 HX^][1=Worl<H
# 802 4900 HX^][1=Worl<G
# 807 4875 HY^][1=Worl<G
# 808 4800 HY^][1=Worl<F
# 809 4743 HY^][1<Worl<F
# 812 4716 HY_][1<Worl<F
# 820 4707 HY_][0<Worl<F
# 827 4682 HY`][0<Worl<F
# 828 4627 HY`][0;Worl<F
# 832 4604 HZ`][0;Worl<F
# 838 4551 HZ`][0:Worl<F
# 846 4512 HZ`]\0:Worl<F
# 848 4461 HZ`]\09Worl<F
# 851 4382 HZ`]\09Worl=F
# 856 4305 HZ`]\09Worl>F
# 858 4230 HZ`]\09Worl?F
# 867 4181 HZ`]\08Worl?F
# 868 4144 HZ`]]08Worl?F
# 869 4097 HZ`]]07Worl?F
# 871 4076 H[`]]07Worl?F
# 874 4003 H[`]]07Worl@F
# 875 3968 H[`]^07Worl@F
# 879 3923 H[`]^06Worl@F
# 880 3852 H[`]^06WorlAF
# 881 3823 H[`^^06WorlAF
# 882 3790 H[`^_06WorlAF
# 885 3763 H[`__06WorlAF
# 886 3738 H[``_06WorlAF
# 887 3669 H[``_06WorlBF
# 896 3662 H[``_/6WorlBF
# 900 3639 H[a`_/6WorlBF
# 909 3572 H[a`_/6WorlCF
# 910 3567 H[a`_.6WorlCF
# 911 3524 H[a`_.5WorlCF
# 912 3501 H[aa_.5WorlCF
# 920 3460 H[aa_.4WorlCF
# 921 3387 H[aa_.4WorlCE
# 922 3348 H[aa_.3WorlCE
# 925 3345 H[aa_-3WorlCE
# 938 3324 H[ba_-3WorlCE
# 939 3323 H[ba_,3WorlCE
# 946 3302 H[bb_,3WorlCE
# 951 3231 H[bb_,3WorlCD
# 952 3194 H[bb_,2WorlCD
# 954 3129 H[bb_,2WorlDD
# 967 3110 H\bb_,2WorlDD
# 979 3093 H]bb_,2WorlDD
# 981 3062 H]bb`,2WorlDD
# 983 2993 H]bb`,2WorlDC
# 985 2964 H]bba,2WorlDC
# 993 2945 H]bca,2WorlDC
# 1000 2878 H]bca,2WorlDB
# 1006 2863 H^bca,2WorlDB
# 1010 2828 H^bca,1WorlDB
# 1019 2811 H^bda,1WorlDB
# 1020 2746 H^bda,1WorlDA
# 1027 2733 H_bda,1WorlDA
# 1031 2722 H`bda,1WorlDA
# 1034 2703 H`cda,1WorlDA
# 1037 2688 H`cea,1WorlDA
# 1045 2679 Hacea,1WorlDA
# 1052 2652 Haceb,1WorlDA
# 1067 2635 Hadeb,1WorlDA
# 1075 2572 Hadeb,1WorlD@
# 1086 2511 Hadeb,1WorlD?
# 1088 2448 Hadeb,1WorlE?
# 1091 2415 Hadeb,0WorlE?
# 1093 2356 Hadeb,0WorlE>
# 1100 2331 Hadec,0WorlE>
# 1104 2324 Hbdec,0WorlE>
# 1106 2267 Hbdec,0WorlE=
# 1109 2206 Hbdec,0WorlF=
# 1111 2201 Hcdec,0WorlF=
# 1118 2178 Hcded,0WorlF=
# 1119 2165 Hcdfd,0WorlF=
# 1123 2134 Hcdfd,/WorlF=
# 1126 2113 Hcdfe,/WorlF=
# 1133 2094 Hcdff,/WorlF=
# 1137 2083 Hcdgf,/WorlF=
# 1139 2066 Hcdgg,/WorlF=
# 1140 2051 Hcegg,/WorlF=
# 1142 2022 Hcegg,.WorlF=
# 1145 1963 Hcegg,.WorlG=
# 1146 1950 Hcfgg,.WorlG=
# 1149 1893 Hcfgg,.WorlH=
# 1153 1890 Hdfgg,.WorlH=
# 1163 1881 Hdfhg,.WorlH=
# 1166 1826 Hdfhg,.WorlI=
# 1168 1799 Hdfhg,-WorlI=
# 1171 1798 Hefhg,-WorlI=
# 1179 1783 Hefhh,-WorlI=
# 1183 1730 Hefhh,-WorlJ=
# 1186 1679 Hefhh,-WorlK=
# 1190 1672 Hefih,-WorlK=
# 1192 1661 Hegih,-WorlK=
# 1200 1656 Hegjh,-WorlK=
# 1204 1607 Hegjh,-WorlL=
# 1218 1560 Hegjh,-WorlM=
# 1220 1515 Hegjh,-WorlN=
# 1224 1490 Hegjh,,WorlN=
# 1225 1467 Hegjh,+WorlN=
# 1228 1458 Hehjh,+WorlN=
# 1235 1437 Hehjh,*WorlN=
# 1243 1418 Hehjh,)WorlN=
# 1252 1415 Hehkh,)WorlN=
# 1254 1360 Hehkh,)WorlN<
# 1258 1307 Hehkh,)WorlN;
# 1259 1264 Hehkh,)WorlO;
# 1263 1213 Hehkh,)WorlO:
# 1264 1172 Hehkh,)WorlP:
# 1267 1123 Hehkh,)WorlP9
# 1268 1110 Hehki,)WorlP9
# 1277 1099 Hehkj,)WorlP9
# 1282 1090 Hehkk,)WorlP9
# 1284 1051 Hehkk,)WorlQ9
# 1290 1004 Hehkk,)WorlQ8
# 1306 997 Hehkl,)WorlQ8
# 1307 990 Heikl,)WorlQ8
# 1308 953 Heikl,)WorlR8
# 1326 908 Heikl,)WorlR7
# 1327 907 Heill,)WorlR7
# 1332 872 Heill,)WorlS7
# 1334 839 Heill,)WorlT7
# 1336 808 Heill,)WorlU7
# 1346 791 Heill,(WorlU7
# 1352 786 Heilm,(WorlU7
# 1355 783 Heiln,(WorlU7
# 1357 768 Heiln,'WorlU7
# 1359 767 Heilo,'WorlU7
# 1366 738 Heilo,'WorlV7
# 1380 711 Heilo,'WorlW7
# 1389 706 Hejlo,'WorlW7
# 1398 681 Hejlo,'WorlX7
# 1406 658 Hejlo,'WorlY7
# 1408 615 Hejlo,'WorlY6
# 1419 602 Hejlo,&WorlY6
# 1457 581 Hejlo,&WorlZ6
# 1468 570 Hejlo,%WorlZ6
# 1474 567 Heklo,%WorlZ6
# 1493 526 Heklo,%WorlZ5
# 1509 507 Heklo,%Worl[5
# 1510 490 Heklo,%Worl\5
# 1524 451 Heklo,%Worl\4
# 1532 442 Heklo,$Worl\4
# 1533 435 Heklo,#Worl\4
# 1538 420 Heklo,#Worl]4
# 1544 407 Heklo,#Worl^4
# 1554 396 Heklo,#Worl_4
# 1555 391 Heklo,"Worl_4
# 1567 390 Hello,"Worl_4
# 1576 353 Hello,"Worl_3
# 1591 350 Hello,!Worl_3
# 1608 349 Hello, Worl_3
# 1618 340 Hello, Worl`3
# 1624 305 Hello, Worl`2
# 1657 298 Hello, Worla2
# 1685 265 Hello, Worla1
# 1686 260 Hello, Worlb1
# 1694 229 Hello, Worlb0
# 1722 200 Hello, Worlb/
# 1743 197 Hello, Worlc/
# 1745 196 Hello, World/
# 1785 169 Hello, World.
# 1843 144 Hello, World-
# 1863 121 Hello, World,
# 1885 100 Hello, World+
# 1941 81 Hello, World*
# 1948 64 Hello, World)
# 1965 49 Hello, World(
# 2091 36 Hello, World'
# 2216 25 Hello, World&
# 2337 16 Hello, World%
# 2352 9 Hello, World$
# 2370 4 Hello, World#
# 2436 1 Hello, World"
# 2450 0 Hello, World!
